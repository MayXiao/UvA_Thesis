# %%
# %matplotlib inline
import logging

import os
import random
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='darkgrid', font_scale=1.4)
from glob import glob
import wandb

# Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader, random_split, Dataset
from torchvision import datasets, transforms, models
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from torchvision.transforms import ToTensor, RandomCrop

from tqdm import tqdm
from sklearn.manifold import TSNE
from PIL import Image
import warnings
warnings.filterwarnings('ignore')
import statistics


import torchvision
import umap
from cycler import cycler

import pytorch_metric_learning
import pytorch_metric_learning.utils.logging_presets as logging_presets
from pytorch_metric_learning import losses, miners, samplers, testers, trainers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
from pytorch_metric_learning.distances import CosineSimilarity
from pytorch_metric_learning.utils.inference import InferenceModel, MatchFinder
from pytorch_metric_learning.utils import common_functions as c_f

logging.getLogger().setLevel(logging.INFO)
logging.info("VERSION %s" % pytorch_metric_learning.__version__)

import fuzzymatcher
from fuzzymatcher import link_table, fuzzy_left_join

from scipy import stats
# Out:
# INFO:root:VERSION 2.1.2

# %%
path = '/var/scratch/mxiao/data/'
os.chdir(path)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Data load

# %%
def remove_tabs(value):
    if isinstance(value, str):
        return value.lstrip('\t')
    return value

# %%
df = pd.read_excel(path + 'TINTIN_bibliography_05082023.xlsx') # loaded image information csv and created df
df.head()
# Out:
#   Global Region    Country  Publication Date          Document Name  \
# 0      \tAfrica  \tAlgeria              2020  The Legend of Tteryel
# 1      \tAfrica   \tAngola              2021  A Resistencia Da Pena
# 2      \tAfrica   \tAngola              2021             Explorando
# 3      \tAfrica   \tAngola              2021  Identidade Abandonada
# 4      \tAfrica    \tBenin              2015             Teddy Bear
#
#                  Document Directory                    Title           Format  \
# 0  ee628c6877967dd5e03e59a09a0dccb6  \tThe Legend of Tteryel          \tComic
# 1  8ded1ce5013fd3b3a019f7d8b499492a  \tA Resistencia Da Pena    \tShort story
# 2  2bddf2fcafdb960d372dec0322317bbd             \tExplorando    \tShort story
# 3  453289c004860e8162bdfcb585cffe69  \tIdentidade Abandonada    \tShort story
# 4  cebc8f67b388c5e271e007ef340dbd84             \tTeddy Bear  \tGraphic Novel
#
#                     Genre    Style      Language Original Language
# 0  \tsupernatural, action  \tmanga            \t                \t
# 1  \tPolitical commentary       \t  \tPortuguese                \t
# 2         \tSlice of life       \t  \tPortuguese                \t
# 3  \tPolitical commentary       \t  \tPortuguese                \t
# 4         \tSlice of life  \tmanga            \t                \t

# %%
namel = list()
subfolder = list()
my_folder = 'model/train' 

for root, dirs, files in os.walk(my_folder):
    for name in dirs:
        for root, dirs, files in os.walk(os.path.join(my_folder,name)):
            for filename in files:
                namel.append(filename)
                subfolder.append(root)

df1 = pd.DataFrame(zip(namel, subfolder), columns = ['name', 'subfolder']) # generated dataframe df1 which contains images' name and comics subfolder name

# %%
df1
# Out:
#                name          subfolder
# 0        1986_1.png   model/train/1986
# 1        1986_2.png   model/train/1986
# 2        1986_3.png   model/train/1986
# 3        1986_4.png   model/train/1986
# 4        1986_7.png   model/train/1986
# ...             ...                ...
# 35637  Zorro_66.png  model/train/Zorro
# 35638  Zorro_67.png  model/train/Zorro
# 35639  Zorro_68.png  model/train/Zorro
# 35640  Zorro_69.png  model/train/Zorro
# 35641  Zorro_70.png  model/train/Zorro
#
# [35642 rows x 2 columns]

# %%
col_list = ['Document Name','Global Region','Country','Publication Date',]
df_info = df[col_list].drop_duplicates()
df_info.rename({'Document Name': 'document_name'}, axis=1, inplace=True) # preprocess(subset&rename) comic information df
df1['subfolder_name'] = df1.subfolder.str.split('/', expand=True)[2]  # preprocess

# %%
df_final = fuzzymatcher.link_table(df1, df_info, 'subfolder_name', 'document_name') # fuzzy join 2 tables using comic's names, since comic on both files are not exactly the same
df_final = df_final.reset_index(drop=True)

# %%
df_final1 = df_final[df_final.match_rank == 1] #fuzzy match creates multiple join, here only subset the top match result

# %%
fuzzy_match_pairs = df_final1[['subfolder_name','document_name']].drop_duplicates()

# %%
df1_match = pd.merge(df1,fuzzy_match_pairs, left_on='subfolder_name', right_on='subfolder_name', how='inner')

# %%
df1_info_fuzzy_match = pd.merge(df1_match,df_info, left_on='document_name', right_on='document_name', how='left')

# %%
def strip_tabs(value):
    if isinstance(value, str):
        return value.strip('\t').strip(' ')
    return value

# %%
df1_info_fuzzy_match = df1_info_fuzzy_match.applymap(strip_tabs)

# %%
# Define the custom bars
custom_bars = [1930, 1990, 2000, 2010, 2020, 2023]

# Create bins based on column values and custom bars
#  pd.cut(df1_info_fuzzy_match['Values'], bins=custom_bars)
df1_info_fuzzy_match['Date_EFB'] = pd.cut(df1_info_fuzzy_match['Publication Date'],bins=custom_bars)

# %%
def class_map(df, new_class_col):
    class_map_df = df[['subfolder_name',new_class_col]].drop_duplicates()
    class_map_dict =  dict(zip(class_map_df['subfolder_name'], class_map_df[new_class_col]))
    return class_map_dict

# %%
year_class_map_dict = class_map(df1_info_fuzzy_match, 'Date_EFB')
country_class_map_dict = class_map(df1_info_fuzzy_match, 'Country')
region_class_map_dict = class_map(df1_info_fuzzy_match, 'Global Region')

# %%
# Set the image transforms
normalize = transforms.Normalize(mean=[0.6195012,0.6195012,0.6195012], std=[0.3307451,0.3307451,0.3307451])
# normalize = transforms.Normalize(mean=[0.53997546,0.53997546,0.53997546], std=[0.36844322,0.36844322,0.36844322])

train_transform = transforms.Compose([
#         transforms.RandomRotation(10),      # rotate +/- 10 degrees
#         transforms.RandomHorizontalFlip(),  # reverse 50% of images
#         transforms.RandomVerticalFlip(p=0.5),
#         transforms.Resize(224),             # resize shortest side to 224 pixels
#         transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.RandomCrop(size=(224,224),pad_if_needed=True), 
        transforms.ToTensor(),
        normalize
    ])

test_transform = transforms.Compose([
        transforms.RandomCrop((224,224),pad_if_needed=True),
        transforms.ToTensor(),
        normalize
    ])

# %%
excluded_subfolders = [] #['Sidequest', 'Stand Still Stay Silent']  # Subfolders to be skipped

class CustomImageFolder(ImageFolder):
    def __init__(self, root, transform=None, target_transform=None, class_mapping=None):
        self.valid_classes = [subfolder for subfolder in os.listdir(root) if subfolder not in excluded_subfolders]
        super().__init__(root, transform=transform, target_transform=target_transform)
        self.classes = [class_mapping[subfolder] for subfolder in self.valid_classes]
        self.class_mapping = class_mapping

    def __getitem__(self, index):
        original_tuple = super().__getitem__(index)
        path, _ = self.samples[index]
        folder_name = os.path.basename(os.path.dirname(path))
        
        if folder_name in excluded_subfolders:
            pass
#             raise RuntimeError(f"Skipping images from subfolder: {folder_name}")
            
        
        new_target = self.class_mapping[folder_name]
        # Extract unique values from the original dictionary
        unique_values = list(set(self.class_mapping.values()))

        # Sort the unique values
        sorted_values = sorted(unique_values)

        # Generate the new dictionary with unique and sorted values as keys
        year_class_mapping = {value: index for index, value in enumerate(sorted_values)}
        new_target_idx = year_class_mapping[new_target]
        return original_tuple[0], new_target_idx #, new_target, folder_name

# %%
unique_values = list(set(year_class_map_dict.values()))
# Sort the unique values
sorted_values = sorted(unique_values)
# Generate the new dictionary with unique and sorted values as keys
year_class_mapping = {index: value for index, value in enumerate(sorted_values)}

# %%
region_class_map_dict
# Out:
# {'1986': 'Europe',
#  '13th Boy': 'East Asia',
#  '1714 Baluarte': 'Europe',
#  '14 days in the desert': 'East Asia',
#  '26 Needled Girl': 'West Asia',
#  '40 Years of Silence': 'West Asia',
#  '5-nen Hibarigumi': 'East Asia',
#  '6People - Alti Adam 1': 'Central Asia',
#  '6People - Alti Adam 2': 'Central Asia',
#  '6People - Alti Adam 3': 'Central Asia',
#  '6People - Alti Adam 4': 'Central Asia',
#  '6People - Alti Adam 5': 'Central Asia',
#  '6People - Alti Adam 6': 'Central Asia',
#  '6People - Alti Adam 7': 'Central Asia',
#  '6People - Alti Adam  8': 'Central Asia',
#  'Abena': 'Africa',
#  'Abisul Clujulu': 'Europe',
#  'Ace Hart in Men of Rubber': 'Europe',
#  'Action-Truyen': 'Southeast Asia',
#  'A Deal With Lucifer': 'Southeast Asia',
#  'Adventures of Amitabh Bachchan-The Lost Idol': 'South Asia',
#  'Adventures of Bongoman': 'Africa',
#  'After Yesterday': 'Europe',
#  'Aganza': 'Africa',
#  'Age of Bronze': 'North America',
#  'Age of Ivory': 'Africa',
#  'AGGA': 'Southeast Asia',
#  'Aguia Negra': 'South America',
#  'Ah Ah Ah!': 'East Asia',
#  'Akado Suzunosuke': 'East Asia',
#  'Akagami no Shirayukihime': 'East Asia',
#  'Akcja Labirynt (Part 1)': 'Europe',
#  'Akira': 'East Asia',
#  'Alexander- The Servent- And The Water of Life': 'Southeast Asia',
#  'Alice Guy - First Lady of Film': 'Europe',
#  'Allman- Los olvidados del infierno': 'South America',
#  'A Luta Contra Canudos': 'South America',
#  'Amalon': 'Southeast Asia',
#  'Amazing Tek Kids': 'Africa',
#  'Anabasis': 'Europe',
#  'Anancy and the Mango': 'North America',
#  'Ananse': 'Africa',
#  'Anderson- Psi-Division- Wiierd': 'Europe',
#  'Andhaka': 'South Asia',
#  'Anepantla': 'Europe',
#  'A New One': 'Africa',
#  'Anime Nyash': 'Europe',
#  'Anne Freaks': 'East Asia',
#  'A Noite dos Palha--os Mudos': 'South America',
#  'Antidote': 'Southeast Asia',
#  'Archie-s Friend Scarlet': 'North America',
#  'Ardal--n': 'Europe',
#  'A Restaurant Nearby': 'East Asia',
#  'Arkin': 'Europe',
#  'Arno': 'Europe',
#  'Asterios Polyp': 'North America',
#  'Astro-idani- Ozivljeni Metuzalemen': 'Europe',
#  'Astronauta- Entropia': 'South America',
#  'A Teacher-s Paradigm': 'Southeast Asia',
#  'Attack of Crescent': 'Southeast Asia',
#  'Aurion': 'Africa',
#  'Avonome v-2': 'Africa',
#  'Awaken': 'South America',
#  'Babetool': 'South America',
#  'Babies For Sale': 'West Asia',
#  'Baby Blue': 'Europe',
#  'Bahadur The White Ghosts Den': 'South Asia',
#  'Bamse Och Jatten Gorm': 'Europe',
#  'Banana Fish': 'East Asia',
#  'Bana': 'Africa',
#  'Bang Bang': 'Africa',
#  'Barajou no Kiss': 'East Asia',
#  'Barbochard': 'Europe',
#  'Barrio minero Alalay': 'South America',
#  'Basaglia il dottore dei matti': 'Europe',
#  'Basila - The Street Crew 1': 'South Asia',
#  'Battle of the Champions': 'Europe',
#  'Bed': 'Europe',
#  'Beijing Pistols': 'East Asia',
#  'Bella At The Bar': 'Europe',
#  'Beloved': 'Europe',
#  'Berserk': 'East Asia',
#  'Beyond the Walls': 'Africa',
#  'Bidu - Caminhos': 'South America',
#  'Biser zla': 'Europe',
#  'Bishoujo Senshi Sailor Moon': 'East Asia',
#  'Black Beth- The Magos of Malice': 'Europe',
#  'Black Jack': 'East Asia',
#  'Black Mage': 'Southeast Asia',
#  'Black Sage': 'Africa',
#  'Blake and Mortimer - The Yellow -M-': 'Europe',
#  'Blizzard in the Jungle': 'East Asia',
#  'Boja per tu': 'Europe',
#  'Bonding': 'Europe',
#  'Boomerang': 'West Asia',
#  'Breathe': 'Africa',
#  'Bring me to Life': 'North America',
#  'Broccoli and Cauliflower': 'Southeast Asia',
#  'Bubbles of Memories': 'Middle East',
#  'Buch der Schatten': 'Europe',
#  'Buen Habito': 'South America',
#  'Bumbardai': 'East Asia',
#  'Burn Thread': 'Africa',
#  'Call me Nathan': 'Europe',
#  'Caminantes': 'Europe',
#  'Can we be friends-': 'Southeast Asia',
#  'Capitao Feio - Identidade': 'South America',
#  'Captain Barbell': 'Southeast Asia',
#  'Captain Garra': 'South America',
#  'Captian Kathal vs the Molom Party': 'South Asia',
#  'Cardcaptor Sakura - Clear Card hen': 'East Asia',
#  'Carpincho': 'South America',
#  'Cat Claw - Maco': 'Europe',
#  'Cat Claw - The final cat': 'Europe',
#  'Centralny Okreg Przemyslowy': 'Europe',
#  'Chanoc- Adventuras de Mar y Selva': 'North America',
#  'Char Chapman - -Safari Spies-': 'Oceania',
#  'Chathurmana': 'South Asia',
#  'Char Chapman - -Valley of the Ages-': 'Oceania',
#  'Charlie Pele - Jenerali Magic': 'Africa',
#  'Chase your Dreams!': 'West Asia',
#  'Chayoma': 'Africa',
#  'CHC - Episodio 1': 'South America',
#  'Cizgi Roman Cetesi': 'West Asia',
#  'Chronicles of the Newborn - Rise of Mlezi': 'Africa',
#  'Clancy of the Overflow': 'Oceania',
#  'Cleverman': 'Oceania',
#  'Clifton - My Dear Wilkinson': 'Europe',
#  'Clockwork': 'Africa',
#  'DEUDA': 'South America',
#  'Cocktail': 'Middle East',
#  'Comic Gianchi': 'Europe',
#  'Confessions of an Introvert': 'Africa',
#  'Co Tien Xanh': 'Southeast Asia',
#  'Cotton Star': 'Africa',
#  'Crimson Comet': 'Oceania',
#  'CrossGen Chronicles': 'North America',
#  'Crow Girl': 'North America',
#  'Crveni obavestajac': 'Europe',
#  'Cuisine Chinoise': 'East Asia',
#  'Curse of the Red Velvet': 'Southeast Asia',
#  'Daemonium Comics': 'Europe',
#  'Dallas': 'Europe',
#  'Danger Girl': 'North America',
#  'Dani 2': 'Africa',
#  'Dans Le Taxi': 'Middle East',
#  'Daogopak': 'Europe',
#  'Daughter-in-Law (Nuora)': 'East Asia',
#  'Days of Sand': 'Europe',
#  'DC Artists': 'South Asia',
#  'Dead Ringer': 'Europe',
#  'Debout Congolais': 'Africa',
#  'Decomposition Jones': 'Europe',
#  'Defence against the Penguins': 'Southeast Asia',
#  'Dem- Dem': 'Africa',
#  'Dementia': 'South America',
#  'Demon-s Drive': 'Europe',
#  'Des Pekinois Pas Tres Civilises': 'East Asia',
#  'De Tweede Pimpernel': 'Europe',
#  'Dharma Punks': 'Oceania',
#  'Diablo': 'South America',
#  'Diabolik (La lama della vendetta)': 'Europe',
#  'Diego Armando Maradona': 'Europe',
#  'Diego Rivera': 'North America',
#  'Di Iche': 'Africa',
#  'Diplomatic Mission': 'Europe',
#  'Divisione fate': 'Middle East',
#  'Doc Savage': 'North America',
#  'Dolf Staal': 'Europe',
#  'Dominion Jack': 'North America',
#  'Don Quijote': 'South America',
#  'Dora': 'South America',
#  'Dracula': 'South Asia',
#  'Dragens Oye': 'Europe',
#  'Dreadnoughts-Breaking Ground': 'Europe',
#  'Dream Ocean': 'Southeast Asia',
#  'Dream Walker Muca': 'Southeast Asia',
#  'Drifting Classroom': 'East Asia',
#  'Duck Feet': 'North America',
#  'Durjoy 15': 'South Asia',
#  'Durjoy 1': 'South Asia',
#  'Dziewieciu z nieba': 'Europe',
#  'Echo in Hai Men': 'East Asia',
#  'Eden- It-s an Endless World!': 'East Asia',
#  'Eeuwig 1913': 'Europe',
#  'Eislicht': 'Europe',
#  'El 3osba': 'Africa',
#  'El arte de volar': 'Europe',
#  'Elazar': 'Europe',
#  'El Capitan Coraje 11 El fin de un esbirro': 'Europe',
#  'El case de laguna toro': 'South America',
#  'El Congreso de Tucuman': 'South America',
#  'El Congreso de Viena': 'South America',
#  'El Correvolando': 'South America',
#  'El Encargo': 'South America',
#  'El Eternauta': 'South America',
#  'El Faro': 'Europe',
#  'ElfQuest': 'North America',
#  'El Hipnotizador': 'South America',
#  'El Jefe': 'South America',
#  'El Jinete Fantasma': 'South America',
#  'El lado oscuro de Otorgues': 'South America',
#  'Ella entro por la ventana del bano': 'South America',
#  'El Loco Chavez- Gato': 'South America',
#  'El Malson': 'Europe',
#  'El Manque - El Hombre de Barro': 'South America',
#  'El Manque - Las dos gallinas': 'South America',
#  'El Verdagazo': 'South America',
#  'El violeta': 'Europe',
#  'Emotional Support Monster': 'Africa',
#  'Emperor Doom': 'North America',
#  'En Kahraman Ridvan': 'West Asia',
#  'En Paraguay': 'South America',
#  'Entwinded A Recurrent Romance': 'Oceania',
#  'Ermek the Batyr- Legend of the Forgotten Times': 'Central Asia',
#  'Evolution': 'East Asia',
#  'Exit': 'Europe',
#  'Expectations!': 'Africa',
#  'Eyes': 'Europe',
#  'Fair Game': 'Africa',
#  'Fairy Tales gone Spandex': 'Europe',
#  'Fantax - Le Gentleman fantome': 'Europe',
#  'Far from Reality': 'Africa',
#  'File de Hronic Vitejesc': 'Europe',
#  'Final Game': 'Middle East',
#  'Finger': 'Europe',
#  'First One': 'Europe',
#  'Fluttering Fleeing and Freeing': 'Southeast Asia',
#  'Fly me to Babylon': 'Middle East',
#  'Fly - The Song of frogs': 'East Asia',
#  'Forgiveness': 'East Asia',
#  'Fra Joan Gari': 'Europe',
#  'Franklin Gonzales - The Last Song': 'West Asia',
#  'Frida': 'Europe',
#  'Fullmetal Alchemist': 'East Asia',
#  'Full Metal Panic!': 'East Asia',
#  'Fulmine Mascherato': 'Europe',
#  'Funky Koval': 'Europe',
#  'Gainarii': 'Europe',
#  'Gallus': 'South Asia',
#  'Galvarino': 'South America',
#  'Generational Love': 'North America',
#  'Golem': 'Europe',
#  'Gennady the Pigeon': 'Europe',
#  'Geno Wars': 'Africa',
#  'Gertrude- The Graphic Diary of Generation Y': 'Europe',
#  'Ghost in the Shell': 'East Asia',
#  'Ghost Residents': 'Southeast Asia',
#  'Gianna': 'Europe',
#  'Going to Top': 'Africa',
#  'Golden Green': 'Middle East',
#  'Golden Tiger VS- Shark Finn': 'Africa',
#  'Gora Gwiazdy': 'Europe',
#  'Great General Mighty Wing': 'East Asia',
#  'Grey Domino': 'Oceania',
#  'Gundala Bernapas Dalam Lumpur': 'Southeast Asia',
#  'Gundala Putera Petir': 'Southeast Asia',
#  'Hagar the Horrible': 'North America',
#  'Hakuba Douji': 'East Asia',
#  'Happy Birthday to Me': 'Middle East',
#  'Harvennus (Thinning)': 'Europe',
#  'HELDEN': 'Europe',
#  'Hemilios': 'Europe',
#  'Heritage found at sea': 'North America',
#  'Herlock Sholmes': 'Europe',
#  'Her name is Kumisay': 'Europe',
#  'Heroes of Shadow': 'Africa',
#  'Hero Hesman': 'Southeast Asia',
#  'Hero Kekere 6': 'Africa',
#  'Hidden Talent': 'West Asia',
#  'Hijos de P': 'South America',
#  'Him Wearing a Skirt': 'East Asia',
#  'Hoc Sinh Chan Kinh': 'Southeast Asia',
#  'Homunculus': 'Europe',
#  'Hope': 'Africa',
#  'Horror (Didha)': 'South Asia',
#  'Horror (Ghun)': 'South Asia',
#  'Horror (Glitch)': 'South Asia',
#  'Horror (Ke)': 'South Asia',
#  'Horror (Koshai)': 'South Asia',
#  'Horror  (Moddho raater train)': 'South Asia',
#  'Horror (Mormohin)': 'South Asia',
#  'Horror (Mukchor)': 'South Asia',
#  'Horror (Nightmare)': 'South Asia',
#  'Horror (Nil Chokh)': 'South Asia',
#  'Horror (Nir Atonko)': 'South Asia',
#  'Horror (Rakkhosh razze bhoot)': 'South Asia',
#  'Horror (Romapod Babur Ekdin)': 'South Asia',
#  'Horror (Tasty food)': 'South Asia',
#  'Hujan di Tepian Rindu': 'Southeast Asia',
#  'Hunger': 'Europe',
#  'Il delitto Matteotti': 'Europe',
#  'Il mio Salinger': 'Europe',
#  'Inazuma-kun': 'East Asia',
#  'Inspiration': 'Europe',
#  'Intalnire in spatiu': 'Europe',
#  'Intercosmic': 'Southeast Asia',
#  'In The Cold Dark': 'Europe',
#  'In your Paws': 'Southeast Asia',
#  'Isabella - She-Wolf of France': 'Europe',
#  'Islamundo': 'Europe',
#  'Ivanhoe': 'Europe',
#  'Jar of Fools': 'North America',
#  'Jejon in Japan': 'Southeast Asia',
#  'Jet Fury': 'Oceania',
#  'Jibaku Shounen Hanako-kun': 'East Asia',
#  'Jihad': 'Europe',
#  'Jogedan Lelembut': 'Southeast Asia',
#  'Judge Dredd-Adios Rowdy Yates': 'Europe',
#  'Judge Dredd - Ratfink': 'Europe',
#  'Judoka': 'South America',
#  'Justine-Messenger of Justice': 'Europe',
#  'Kagerou Nostalgia': 'East Asia',
#  'Kaikisen': 'East Asia',
#  'Kaiko-s Path to Courtship': 'East Asia',
#  'Kajaani': 'Europe',
#  'Kanaboshi Kinta': 'East Asia',
#  'Kaptan Onedin': 'West Asia',
#  'Karugua y Voty': 'South America',
#  'Katerina in Athens': 'Europe',
#  'Katipunera Warrior': 'Southeast Asia',
#  'Kayin and Abeni': 'Africa',
#  'Kazakhman Batyr': 'Central Asia',
#  'Keiden Kaupunki': 'Europe',
#  'Ken Games- Piedra': 'Europe',
#  'Keshka': 'Europe',
#  'Khkhkh': 'Middle East',
#  'Khulan': 'Oceania',
#  'Kids These Days': 'Europe',
#  'King Shaka - Zulu Legend': 'Africa',
#  'Koikai': 'Africa',
#  'Korporativni pandemonijum': 'Europe',
#  'Kotolan mies ja loinen': 'Europe',
#  'Kotu Kedi Serafettin': 'West Asia',
#  'Kowakawaii01- Grim': 'Africa',
#  'Kroo': 'Africa',
#  'Krvolok iz Tanipura': 'Europe',
#  'Ksatria Lelana': 'Southeast Asia',
#  'Kuga': 'Europe',
#  'Kurs na Polwysep Jork': 'Europe',
#  'Kurt Dunder in Africa': 'Europe',
#  'Kusumadinata': 'Southeast Asia',
#  'Kwezi': 'Africa',
#  'La Batalla de Tacuarembo': 'South America',
#  'La Boite a Voeux': 'East Asia',
#  'La casa de los susurros': 'Europe',
#  'La condenada': 'South America',
#  'Lady S - A Second of Eternity': 'Europe',
#  'La Guerra Grande': 'South America',
#  'Lake of Tears': 'Africa',
#  'La Legende des Dieux': 'Africa',
#  'La loi de yeviosio': 'Africa',
#  'Lamis': 'Africa',
#  'LAmour Sous La Lune': 'East Asia',
#  'Lana w kosmosie (Part 5)': 'Europe',
#  'Lanternjack': 'Europe',
#  'La partida dAuale': 'Europe',
#  'La planete encore': 'Europe',
#  'La porta daurada': 'Europe',
#  'Larami': 'Europe',
#  'La Segua': 'South America',
#  'Last Hope': 'Southeast Asia',
#  'Last Moments': 'Europe',
#  'Las Vacanas': 'South America',
#  'Lathial': 'South Asia',
#  'Le Flic de Gnasville': 'Africa',
#  'Legend of Tianma': 'East Asia',
#  'Le Grand Saut': 'East Asia',
#  'Le Malheur De Falonne': 'Africa',
#  'Le meilleur des mondes possible': 'Africa',
#  'Le Resto Denfer': 'Africa',
#  'Le reveil du genie': 'Africa',
#  'Leroe dei due mari': 'Europe',
#  'Les hommes venus des etoiles': 'Europe',
#  'Lex Brand- Morphine': 'Europe',
#  'L-home caiman': 'Europe',
#  'Libera Nos A Malo': 'Southeast Asia',
#  'Life and adventure in Kangebao': 'Europe',
#  'Lillith-s World (Reup)': 'Europe',
#  'Liona Universe Reboot': 'South America',
#  'Little Tiger -Pichinahuel- 1': 'South America',
#  'Little Tiger -Pichinahuel- 2': 'South America',
#  'Little Warm Hearted Guest': 'Europe',
#  'Lola and the worlds of Rodeo': 'South America',
#  'Long Than Tuong': 'Southeast Asia',
#  'L-orphelin Et Le Livre': 'Africa',
#  'Lost Days': 'Europe',
#  'Lost - Found': 'Southeast Asia',
#  'Lost Nightmare': 'Europe',
#  'Luck of the Honest Man': 'Southeast Asia',
#  'Lucky Luke - Daisy Town': 'Europe',
#  'Lucky': 'Europe',
#  'Luna- Ares': 'Europe',
#  'Luna- Raspadanje': 'Europe',
#  'Lustration': 'Oceania',
#  'Macerayi Seven Adam': 'West Asia',
#  'Macu Picu': 'Europe',
#  'Majambazi': 'Africa',
#  'Manduka The Lucky Astrologer': 'South Asia',
#  'MANU- Altiplano': 'South America',
#  'Marco by Demon Dude': 'Europe',
#  'Marie Curie': 'Europe',
#  'Markets': 'Africa',
#  'Marlene': 'Europe',
#  'Mars Ravelo-s Darna': 'Southeast Asia',
#  'Mat Jenin': 'Southeast Asia',
#  'Max Debris- Ispovest pravog krivotvoritelja': 'Europe',
#  'Mbuze': 'Africa',
#  'Medallion': 'Europe',
#  'Mein Hero-Bin Qasim Town-Importance of City Sanitation-Sindh Education Foundation': 'South Asia',
#  'Mein Hero-Lyari Guardians': 'South Asia',
#  'Mein Hero-ORANGI Vanguard-Entrepreneurship-Primary Gulshan E Ghazi Campus-DIL foundation': 'South Asia',
#  'Mein Hero-ORANGI Vanguard-Internet Safety-ASMAAN Campus-DIL foundation': 'South Asia',
#  'Mein Hero-ORANGI Vanguard-Overcoming Disabilities-AL Mansoor Campus-DIL foundation': 'South Asia',
#  'Mein Hero-ORANGI Vanguard-Personal Hygiene-Paradise Campus-DIL foundation': 'South Asia',
#  'Mein Hero-ORANGI Vanguard-Road Safety-Secondary School Rehmat Chowk-DIL foundation': 'South Asia',
#  'Mein Hero-SOS Crew': 'South Asia',
#  'Mein Hero': 'South Asia',
#  'Melenetane': 'Africa',
#  'Metin Annesini Ariyor': 'West Asia',
#  'Mhare': 'Africa',
#  'Mica epopee': 'Europe',
#  'Mirko - La Metropoli Diabolica': 'Europe',
#  'Mirror Mirror': 'Africa',
#  'Missing Piece': 'East Asia',
#  'Moa': 'Oceania',
#  'Mom-s Pakhlava': 'West Asia',
#  'Moon Girls': 'Africa',
#  'Mosquito': 'West Asia',
#  'Mother Ghoul': 'Africa',
#  'Mr and Mrs Van Helsing': 'Europe',
#  'Ms- Shabash 3': 'South Asia',
#  'Ms- Shabash- Attack of the Auntybots': 'South Asia',
#  'Ms- Shabash- The whitewash factor': 'South Asia',
#  'Ms Underworld-s Evolution': 'Southeast Asia',
#  'Munchen 1945': 'Europe',
#  'Myanmar Silent Horror- Night Story': 'Southeast Asia',
#  'My Beautiful Aunt': 'Europe',
#  'My Dear Friend': 'Africa',
#  'Nagraj Strikes - The attack of Coronaman': 'South Asia',
#  'Naruto': 'East Asia',
#  'Nell-Impero degli Incas': 'Europe',
#  'Neomad-Space Junk': 'Oceania',
#  'New Borisfen': 'Europe',
#  'Newborne-s parallel lines': 'Europe',
#  'Ngoda Chronicles': 'Africa',
#  'Nicola R-esistenza Precaria': 'Europe',
#  'Nicoptine': 'Middle East',
#  'Night Bus': 'East Asia',
#  'Nocturne': 'South America',
#  'No End': 'Europe',
#  'Nofret': 'Europe',
#  'Northern Lights- The Valley of the Trolls': 'Europe',
#  'Not alone': 'Middle East',
#  'Oasis': 'Europe',
#  'Obracun u Krezle-sitiju': 'Europe',
#  'O Enfermeiro': 'South America',
#  'OKSI': 'Europe',
#  'Old Friend': 'Middle East',
#  'Old traditions- new dreams': 'Africa',
#  'Omerta': 'Africa',
#  'Once upon a tale': 'Europe',
#  'One Armed Beast': 'North America',
#  'One Love': 'Africa',
#  'One Shot': 'Southeast Asia',
#  'Oppfinneren (The Inventor)': 'Europe',
#  'Orbital 1 - Scars': 'Europe',
#  'Orwell': 'Europe',
#  'Otger Catalo': 'Europe',
#  'Otsonipaivakirjat': 'Europe',
#  'OURUM': 'South America',
#  'Overdrive': 'Africa',
#  'Paper Angels': 'Africa',
#  'Oyasumi Punpun': 'East Asia',
#  'Pandora-s Scar-Fanged Shadows': 'Southeast Asia',
#  'ParaDox': 'Africa',
#  'Pass By Tomorrow': 'Africa',
#  'Patrullera': 'South America',
#  'Path to the Future paved with memoria gems': 'Europe',
#  'Pause': 'Africa',
#  'Pawpaw': 'Africa',
#  'Peau de Banane': 'Africa',
#  'Perceptions- Kaino': 'Africa',
#  'Perihan': 'West Asia',
#  'Persepolis': 'Middle East',
#  'Peter en de Wolf': 'Europe',
#  'Phantasm - The Death List': 'Europe',
#  'Phantom Ranger': 'Oceania',
#  'Phi': 'Africa',
#  'Piccola Maschera': 'Europe',
#  'Pictures and Petals': 'Middle East',
#  'Pirozhki': 'Europe',
#  'Pishach Kahni': 'South Asia',
#  'Poisson': 'East Asia',
#  'Porcelain- A Gothic Fairy Tale': 'Europe',
#  'Poselstwo do Gniezna': 'Europe',
#  'Post-Scriptum': 'Europe',
#  'Pour Le Meilleur Et Le Pire': 'Africa',
#  'Pressure': 'West Asia',
#  'Princess Frog': 'Europe',
#  'Prinde Visul!': 'Europe',
#  'Proud Heart-The Love of Achilles': 'Oceania',
#  'Pulakeshi II': 'South Asia',
#  'Punk': 'Europe',
#  'Qahera': 'Africa',
#  'Quina revetlla!': 'Europe',
#  'Quintstar - 48-Hour': 'Europe',
#  'Quique Hache Detective': 'South America',
#  'Quixotic Elixir': 'Middle East',
#  'Ragnarok- Fimbulvinter': 'Europe',
#  'Rahingard - Werenval': 'Europe',
#  'Raid on Istanbul': 'Europe',
#  'Raio Negro': 'South America',
#  'Random Number': 'Europe',
#  'Ranma': 'East Asia',
#  'Raruurien': 'Southeast Asia',
#  'Raven Forest': 'East Asia',
#  'Razor-man (ComicUp)': 'Africa',
#  'Razor-man': 'Africa',
#  'REAL': 'East Asia',
#  'Rebirth': 'Central Asia',
#  'Regreso a Tuyuti': 'South America',
#  'Reichkameraden': 'South America',
#  'Remember Andy Xenon-': 'Europe',
#  'Replacement': 'Southeast Asia',
#  'Return': 'Africa',
#  'Reves Brises': 'East Asia',
#  'Rex': 'Europe',
#  'Rise in Peace': 'Africa',
#  'Rod': 'Europe',
#  'Romeu e Julieta': 'South America',
#  'Ron Khaltoo': 'Africa',
#  'Roopmati': 'South Asia',
#  'Rovik': 'Africa',
#  'Roy of The Royers-Euro Adventure': 'Europe',
#  'Rufus Marigold': 'Oceania',
#  'Ruhan Ruhan': 'South Asia',
#  'Sabab Majghol': 'Africa',
#  'Safe-Land': 'Africa',
#  'Salon Tarek El Khurafi': 'Middle East',
#  'Sama-s Mother': 'Middle East',
#  'SAM': 'Europe',
#  'Sang Maha Guru': 'Southeast Asia',
#  'Sarmasik': 'West Asia',
#  'Sarutobi Sasuke': 'East Asia',
#  'Savage Dragon': 'North America',
#  'Save a Life': 'Africa',
#  'Secret Agent X9': 'Oceania',
#  'Seduction': 'Africa',
#  'Sembadra Ilang': 'Southeast Asia',
#  'Serendipity - Pilot- Stroke of Luck': 'Southeast Asia',
#  'Shabash- Kathal v Shabash': 'South Asia',
#  'Shaderunners': 'Middle East',
#  'Shadow': 'Middle East',
#  'Share Cliff': 'Oceania',
#  'Sheeba and The Private Detectives-The Case of The Disappearing Animals': 'South Asia',
#  'Sheeba and The Private Detectives-The Case of The Lost Calf': 'South Asia',
#  'Shhh!': 'Europe',
#  'Shine': 'Africa',
#  'ShowDown - Chaos Rising': 'Africa',
#  'Sidequest': 'Europe',
#  'Skip Beat!': 'East Asia',
#  'Skrankpa L-homme De Bon Sens': 'Africa',
#  'Sky High- Karma': 'East Asia',
#  'Slussz kulcs klan': 'Europe',
#  'SmartLife': 'Africa',
#  'Sniper(Al Kanass)': 'Africa',
#  'Snowball': 'Middle East',
#  'Socrate': 'Europe',
#  'Solo Leveling': 'East Asia',
#  'Solstoria': 'North America',
#  'Soredemo Sekai wa Utsukushii': 'East Asia',
#  'Soy Toxico': 'South America',
#  'Spartacus son of the rebellious copper': 'Europe',
#  'Spawn': 'North America',
#  'Spectrum': 'North America',
#  'Spirou and Fantasio in New York': 'Europe',
#  'Spirou and Fantasio': 'Europe',
#  'Spotkanie': 'Europe',
#  'Sredni Vashtar': 'Europe',
#  'Stand Still Stay Silent': 'Europe',
#  'Star Wars Annual': 'North America',
#  'Stas and Nelly are the king of elephants': 'Europe',
#  'Steel Punch': 'Europe',
#  'Steve Larabee': 'Europe',
#  'Strange Adventures - The Invisible Space-Dog': 'North America',
#  'Strange Adventures - The Toy Soldier War': 'North America',
#  'Strange Adventures - War with the Giant Frogs': 'North America',
#  'Strange Encounter': 'Southeast Asia',
#  'Strays': 'North America',
#  'Sukhu and Dukhu': 'South Asia',
#  'Sulfur and Salt': 'Europe',
#  'Sundown Horizon': 'Africa',
#  'Sunshine': 'Oceania',
#  'Super Azaiz': 'Africa',
#  'Super Commando Dhruva - The Struggle with Depression': 'South Asia',
#  'Super-Dud': 'Africa',
#  'Super Proxies': 'Southeast Asia',
#  'Super X- na Tribo dos Machadinhas': 'South America',
#  'Suske en Wiske': 'Europe',
#  'Tagar': 'Europe',
#  'Tales Of The Lucky Girl': 'Africa',
#  'Tata Piluco': 'South America',
#  'Tatashe': 'Africa',
#  'Taxi Brousse': 'Africa',
#  'Team Muhafiz and The Charity Shakedown': 'South Asia',
#  'Team Muhafiz and The Child Raiders': 'South Asia',
#  'Team Muhafiz and The Mystery of The Disappearing Mangroves': 'South Asia',
#  'Team Muhafiz and The Mystery of The Toxic Lands': 'South Asia',
#  'Technotize': 'Europe',
#  'Teddy Bear': 'Africa',
#  'Teddy Wonderland': 'Southeast Asia',
#  'Terra de foc': 'Europe',
#  'Tffffuj! Do bani z takim komiksem!': 'Europe',
#  'The 13th Floor': 'Europe',
#  'The adventures of the cat Chornolapenko': 'Europe',
#  'The adventures of Timko-hunter': 'Europe',
#  'The Artist': 'Middle East',
#  'The Belonging': 'Africa',
#  'The Big Bang': 'Europe',
#  'The Black Doctor': 'Europe',
#  'The Bluecoats': 'Europe',
#  'The Border': 'Middle East',
#  'The Bride of the Nile': 'Africa',
#  'The Burger Refuses': 'Southeast Asia',
#  'The Cat': 'Middle East',
#  'The Celestial Zone-Bandit of Bandits': 'Southeast Asia',
#  'The Cook': 'Africa',
#  'The Deep-Here Be Dragons': 'Oceania',
#  'The Divine': 'Middle East',
#  'The Dragon and the Ghost': 'Europe',
#  'The Dragon of Lake Chini': 'Southeast Asia',
#  'The Dream Catcher': 'Europe',
#  'The Educator - A healthy learning environment': 'Middle East',
#  'The Eldritch Kid-Whisky and Hate': 'Oceania',
#  'The Eye Biter': 'Middle East',
#  'The Fiend in the Forest': 'Europe',
#  'The Fifth Element': 'Africa',
#  'The fifth law of robotics is abduction': 'Europe',
#  'The Gift of Goddess Ai': 'Europe',
#  'The Good Ones': 'Southeast Asia',
#  'The Heading Dog Who Split in Half': 'Oceania',
#  'The House of the Late': 'Africa',
#  'The Inhabitants': 'Oceania',
#  'The King in a Parrots Body': 'South Asia',
#  'The land of Magicians': 'Europe',
#  'The last shop on the street': 'Europe',
#  'The Legend of Tteryel': 'Africa',
#  'The Losers': 'Europe',
#  'The Lunar Cycle': 'Middle East',
#  'The man who could see death': 'North America',
#  'The Marquis of Anaon': 'Europe',
#  'The Marriage of a Bull and a Bullfighter': 'Europe',
#  'The Mountains Ablaze': 'Europe',
#  'The Night of Ghosts': 'East Asia',
#  'The Oysters of Time': 'Europe',
#  'The Pecheneg Seige of Kyiv': 'Europe',
#  'The Pernach Master': 'Europe',
#  'The PiRats': 'South America',
#  'The Priest': 'Africa',
#  'The Redemption of Tanggang': 'Southeast Asia',
#  'The Return of Mamay': 'Europe',
#  'The Revolution that gave birth to Haiti': 'South America',
#  'The Sea Girl and the Prince': 'East Asia',
#  'The Secret of Frequency A': 'East Asia',
#  'The song we didn-t know': 'Europe',
#  'The Vacant Lot': 'Middle East',
#  'The Vacation': 'Africa',
#  'The Voice of the Master(A gazda hangja)': 'Europe',
#  'The Void': 'Africa',
#  'The Well by the House on the Hill': 'Europe',
#  'The Wild Pigeons of Clearwater Cliff': 'East Asia',
#  'The Witch and the Warrior': 'South Asia',
#  'The Witch Door': 'Europe',
#  'The Witness': 'Africa',
#  'The World Ends With You': 'Europe',
#  'They Are Our Parents': 'Africa',
#  'Thomas the Rhymer': 'North America',
#  'Thunder': 'North America',
#  'Tiempo': 'South America',
#  'Tiger- Tiger': 'Europe',
#  'Tikiri Leah': 'South Asia',
#  'Time Machine': 'Africa',
#  'Tim L-audace et les Amazones': 'Europe',
#  'Timun': 'Southeast Asia',
#  'Tintin and the Secret of the Unicorn': 'Europe',
#  'Titan': 'Africa',
#  'Today is the last day of the rest of your life': 'Europe',
#  'Tokyo Ghoul': 'East Asia',
#  'Tomie': 'East Asia',
#  'Torn': 'Oceania',
#  'Tough Marriage Life': 'Africa',
#  'Trang Quynh': 'Southeast Asia',
#  'Treasure Island': 'Europe',
#  'Trinitarios': 'South America',
#  'Tripura': 'South Asia',
#  'Troia Dobrogeana': 'Europe',
#  'Tsunami': 'Oceania',
#  'Turma da Monica Jove': 'South America',
#  'Tyl-s Watch': 'Europe',
#  'Ty quay': 'Southeast Asia',
#  'Udayana': 'South Asia',
#  'Ugar- Der letzte neandertaler': 'Europe',
#  'Ultima Recomensa': 'Europe',
#  'Un Carpintero en la Guerra del Chaco': 'South America',
#  'Un Coup de Peinture': 'Africa',
#  'Under Regnbuen': 'Europe',
#  'Under the Influence': 'Africa',
#  'UnDivine': 'North America',
#  'United Stars': 'Africa',
#  'Un monde meilleur': 'Africa',
#  'Un Sogno': 'Europe',
#  'U-S-A-': 'Africa',
#  'Vainglorious': 'Oceania',
#  'Valas': 'Europe',
#  'Valerian and Laureline - The Empire of a Thousand Planets': 'Europe',
#  'Valhalla': 'Europe',
#  'Vamova deca': 'Europe',
#  'Vam': 'Europe',
#  'Varda': 'West Asia',
#  'Veni- Vidi- Divisam (I came- I saw- I divided)': 'West Asia',
#  'Versailles no Bara': 'East Asia',
#  'Vibe': 'Africa',
#  'Vicki Lante': 'Europe',
#  'Vincent Van Gogh': 'Europe',
#  'Vincent': 'Europe',
#  'Vom Anfang': 'Europe',
#  'Vowels': 'Oceania',
#  'Waiting': 'Middle East',
#  'Walking with Samuel': 'Europe',
#  'WARD': 'Europe',
#  'Way of the Rat': 'North America',
#  'Where does your money go-': 'Europe',
#  'Wiedzmin': 'Europe',
#  'Within': 'Europe',
#  'Words That We Couldn-t Say': 'Southeast Asia',
#  'XIII - Where the Indian Walks': 'Europe',
#  'XYZ': 'North America',
#  'Yakutia': 'Europe',
#  'Yasania': 'Middle East',
#  'Yhesti yhes kymmenennes paikas': 'Europe',
#  'You Lit Up My Life': 'Middle East',
#  'YRR': 'Europe',
#  'Zaalim Manjha Cell No- 9': 'South Asia',
#  'Zaginiony swiat': 'Europe',
#  'Zavalli Polat 1': 'West Asia',
#  'Zavalli Polat 2': 'West Asia',
#  'Zorro': 'Europe'}

# %%
# train_dataset = CustomImageFolder(root="model/train", transform=train_transform, class_mapping = region_class_map_dict)
# val_dataset = CustomImageFolder(root="model/val", transform=test_transform, class_mapping = region_class_map_dict)
test_dataset = CustomImageFolder(root="model/test", transform=test_transform, class_mapping = year_class_map_dict)

# %%
# valid_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %% [markdown]
# ### Pretrain embedding

# %%
import faiss

# %%
# Efficientnet
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_name('efficientnet-b0',include_top=False).to(device)

# %%
model
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6-7): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9-10): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12-14): 3 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_swish): MemoryEfficientSwish()
# )

# %%
import torch
torch.cuda.empty_cache()

# %%
def create_faiss_index(feature_dim):
    res = faiss.StandardGpuResources()
    index = faiss.IndexFlatL2(feature_dim)
    gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
    return gpu_index

# %%
def create_embeddings_and_index(model, dataloader, index):
    model.eval()
    with torch.no_grad():  # No need to track gradients
        for i, (inputs, labels) in enumerate(dataloader):
            inputs = inputs.to(device)
            embeddings = model(inputs)
            index.add(embeddings.cpu().numpy())
    return index

# %%
model = model.to(device)
model.eval()
batch_size = 32
embeddings = []
labels = []

with torch.no_grad():
    for batch in test_dataloader:
        inputs, targets = batch
        inputs = inputs.to(device)
        outputs = model(inputs)
        embeddings.append(outputs.cpu().numpy().reshape(outputs.shape[0], -1))  # Corrected

#         embeddings.append(outputs.cpu().numpy())
        labels.append(targets.numpy())

embeddings = np.vstack(embeddings)
# labels = np.concatenate(labels)

# %%
labels = np.hstack(labels)

# %%
embeddings.shape
# Out:
# (17958, 1280)

# %%
dimension = embeddings.shape[1]  # Dimension of the embeddings
index = faiss.IndexFlatL2(dimension)
index = faiss.index_cpu_to_all_gpus(index)  # Make use of all GPUs

# %%
index.add(embeddings)

# %%
# Now you can use the index for k-NN search
k = 5
D, I = index.search(embeddings, k)  # sanity check
print(I[:5])  # Nearest neighbors of the first 5 queries
# print(D[:5])  # Distances to the nearest neighbors of the first 5 queries
# Out:
# [[    0  4930  9724  7643  3665]
#  [    1  5426 17765 16269  1454]
#  [    2 10448 13509   691  2452]
#  [    3 13930  6595 16135 11414]
#  [    4  1186 10416   349 10591]]

# %%
I[:5][:,:]
# Out:
# array([[    0,  4930,  9724,  7643,  3665],
#        [    1,  5426, 17765, 16269,  1454],
#        [    2, 10448, 13509,   691,  2452],
#        [    3, 13930,  6595, 16135, 11414],
#        [    4,  1186, 10416,   349, 10591]])

# %%
neighbor_labels = labels[I]

# %%
neighbor_labels[:5]
# Out:
# array([[3, 3, 1, 3, 3],
#        [3, 3, 3, 4, 3],
#        [3, 3, 2, 4, 3],
#        [3, 4, 3, 4, 3],
#        [3, 2, 3, 3, 3]])

# %%
predicted_labels = stats.mode(neighbor_labels, axis=1)[0]

# %%
from sklearn import metrics

# Assuming you have the true labels (y_true) and predicted labels (y_pred)
# y_true: true labels of shape (n_samples,)
# y_pred: predicted labels of shape (n_samples,)
y_pred = predicted_labels.reshape(-1)
y_true = labels
# Calculate accuracy
accuracy = metrics.accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Calculate precision, recall, and F1-score for each class
precision = metrics.precision_score(y_true, y_pred, average=None)
recall = metrics.recall_score(y_true, y_pred, average=None)
f1_score = metrics.f1_score(y_true, y_pred, average=None)

# Print precision, recall, and F1-score for each class
for i in range(len(precision)):
    print("Class {}: Precision={}, Recall={}, F1-score={}".format(i, precision[i], recall[i], f1_score[i]))

# Calculate macro-average precision, recall, and F1-score
macro_precision = metrics.precision_score(y_true, y_pred, average='macro')
macro_recall = metrics.recall_score(y_true, y_pred, average='macro')
macro_f1_score = metrics.f1_score(y_true, y_pred, average='macro')
print("Macro-average Precision:", macro_precision)
print("Macro-average Recall:", macro_recall)
print("Macro-average F1-score:", macro_f1_score)

# Calculate weighted-average precision, recall, and F1-score
weighted_precision = metrics.precision_score(y_true, y_pred, average='weighted')
weighted_recall = metrics.recall_score(y_true, y_pred, average='weighted')
weighted_f1_score = metrics.f1_score(y_true, y_pred, average='weighted')
print("Weighted-average Precision:", weighted_precision)
print("Weighted-average Recall:", weighted_recall)
print("Weighted-average F1-score:", weighted_f1_score)
# Out:
# Accuracy: 0.6070275086312507
# Class 0: Precision=0.546242774566474, Recall=0.4184887904788265, F1-score=0.47390691114245415
# Class 1: Precision=0.4638009049773756, Recall=0.2122153209109731, F1-score=0.2911931818181818
# Class 2: Precision=0.4306083650190114, Recall=0.24539544962080173, F1-score=0.31262939958592134
# Class 3: Precision=0.6426800871328776, Recall=0.8799753162604135, F1-score=0.7428372981420386
# Class 4: Precision=0.45691906005221933, Recall=0.09668508287292818, F1-score=0.15959872321021432
# Macro-average Precision: 0.5080502383495916
# Macro-average Recall: 0.37055199202878863
# Macro-average F1-score: 0.396033102779762
# Weighted-average Precision: 0.5731324115396701
# Weighted-average Recall: 0.6070275086312507
# Weighted-average F1-score: 0.5614273802247016

# %%
from sklearn import metrics

# Assuming you have the true labels (y_true) and predicted labels (y_pred)
# y_true: true labels of shape (n_samples,)
# y_pred: predicted labels of shape (n_samples,)
y_pred = predicted_labels.reshape(-1)
y_true = labels
# Calculate accuracy
accuracy = metrics.accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Calculate precision, recall, and F1-score for each class
precision = metrics.precision_score(y_true, y_pred, average=None)
recall = metrics.recall_score(y_true, y_pred, average=None)
f1_score = metrics.f1_score(y_true, y_pred, average=None)

# Print precision, recall, and F1-score for each class
for i in range(len(precision)):
    print("Class {}: Precision={}, Recall={}, F1-score={}".format(i, precision[i], recall[i], f1_score[i]))

# Calculate macro-average precision, recall, and F1-score
macro_precision = metrics.precision_score(y_true, y_pred, average='macro')
macro_recall = metrics.recall_score(y_true, y_pred, average='macro')
macro_f1_score = metrics.f1_score(y_true, y_pred, average='macro')
print("Macro-average Precision:", macro_precision)
print("Macro-average Recall:", macro_recall)
print("Macro-average F1-score:", macro_f1_score)

# Calculate weighted-average precision, recall, and F1-score
weighted_precision = metrics.precision_score(y_true, y_pred, average='weighted')
weighted_recall = metrics.recall_score(y_true, y_pred, average='weighted')
weighted_f1_score = metrics.f1_score(y_true, y_pred, average='weighted')
print("Weighted-average Precision:", weighted_precision)
print("Weighted-average Recall:", weighted_recall)
print("Weighted-average F1-score:", weighted_f1_score)
# Out:
# Accuracy: 0.46759104577347144
# Class 0: Precision=0.32655551037006914, Recall=0.46550724637681157, F1-score=0.38384321223709367
# Class 1: Precision=0.2727272727272727, Recall=0.18032786885245902, F1-score=0.21710526315789475
# Class 2: Precision=0.3630246715796219, Recall=0.5415869980879541, F1-score=0.4346825244580856
# Class 3: Precision=0.5628651806968189, Recall=0.7392354696603667, F1-score=0.6391055961668407
# Class 4: Precision=0.42023346303501946, Recall=0.13989637305699482, F1-score=0.20991253644314867
# Class 5: Precision=0.4088397790055249, Recall=0.09622886866059818, F1-score=0.15578947368421053
# Class 6: Precision=0.4578313253012048, Recall=0.11746522411128284, F1-score=0.18696186961869618
# Class 7: Precision=0.4439918533604888, Recall=0.16232315711094564, F1-score=0.23773173391494004
# Class 8: Precision=0.43154761904761907, Recall=0.22979397781299524, F1-score=0.2998965873836608
# Class 9: Precision=0.35799086757990867, Recall=0.2530664945125888, F1-score=0.29652042360060515
# Class 10: Precision=0.4444444444444444, Recall=0.11744386873920552, F1-score=0.18579234972677594
# Macro-average Precision: 0.4081865442861812
# Macro-average Recall: 0.27662504972565477
# Macro-average F1-score: 0.295212870035632
# Weighted-average Precision: 0.4578091919094303
# Weighted-average Recall: 0.46759104577347144
# Weighted-average F1-score: 0.43301301688801114
